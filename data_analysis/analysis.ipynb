# %%
# %sql

SELECT b.city, sum(profit) / sum(amount) *100  as gross_margin_percent
FROM sales_order_detail a
JOIN sales_order_header b
ON a.order_id = b.order_id
GROUP BY city
ORDER BY gross_margin_percent desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>gross_margin_percent</th></tr></thead><tbody><tr><td>Surat</td><td>19.698301113063856</td></tr><tr><td>Allahabad</td><td>18.27727353621641</td></tr><tr><td>Udaipur</td><td>18.15226225955026</td></tr><tr><td>Kolkata</td><td>17.748118699417862</td></tr><tr><td>Delhi</td><td>14.021343778728165</td></tr><tr><td>Thiruvananthapuram</td><td>13.90147856452931</td></tr><tr><td>Pune</td><td>13.55694274364565</td></tr><tr><td>Amritsar</td><td>12.07011315731085</td></tr><tr><td>Gangtok</td><td>7.600454890068234</td></tr><tr><td>Simla</td><td>7.569813062543272</td></tr><tr><td>Goa</td><td>5.51826994780015</td></tr><tr><td>Indore</td><td>5.259962817286167</td></tr><tr><td>Bangalore</td><td>4.283437375481472</td></tr><tr><td>Bhopal</td><td>3.693338421744477</td></tr><tr><td>Lucknow</td><td>2.8353326063249726</td></tr><tr><td>Mumbai</td><td>2.645998674576107</td></tr><tr><td>Kohima</td><td>1.2433840208350837</td></tr><tr><td>Chandigarh</td><td>0.8135464951281809</td></tr><tr><td>Kashmir</td><td>0.07387570412780498</td></tr><tr><td>Patna</td><td>-2.480105076102913</td></tr><tr><td>Hyderabad</td><td>-3.7417018708509353</td></tr><tr><td>Ahmedabad</td><td>-6.184118060435699</td></tr><tr><td>Jaipur</td><td>-7.473203652242953</td></tr><tr><td>Chennai</td><td>-36.40545424675538</td></tr></tbody></table></div>

# %%
# %sql

SELECT category, sub_category, sum(profit) profit
FROM sales_order_detail a
GROUP BY category, sub_category
ORDER BY profit desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>sub_category</th><th>profit</th></tr></thead><tbody><tr><td>Electronics</td><td>Printers</td><td>5964.0</td></tr><tr><td>Furniture</td><td>Bookcases</td><td>4888.0</td></tr><tr><td>Electronics</td><td>Accessories</td><td>3559.0</td></tr><tr><td>Clothing</td><td>Trousers</td><td>2847.0</td></tr><tr><td>Clothing</td><td>Stole</td><td>2559.0</td></tr><tr><td>Electronics</td><td>Phones</td><td>2207.0</td></tr><tr><td>Clothing</td><td>Hankerchief</td><td>2098.0</td></tr><tr><td>Clothing</td><td>T-shirt</td><td>1500.0</td></tr><tr><td>Clothing</td><td>Shirt</td><td>1131.0</td></tr><tr><td>Furniture</td><td>Furnishings</td><td>844.0</td></tr><tr><td>Furniture</td><td>Chairs</td><td>577.0</td></tr><tr><td>Clothing</td><td>Saree</td><td>352.0</td></tr><tr><td>Clothing</td><td>Leggings</td><td>260.0</td></tr><tr><td>Clothing</td><td>Skirt</td><td>235.0</td></tr><tr><td>Clothing</td><td>Kurti</td><td>181.0</td></tr><tr><td>Electronics</td><td>Electronic Games</td><td>-1236.0</td></tr><tr><td>Furniture</td><td>Tables</td><td>-4011.0</td></tr></tbody></table></div>

# %%
# %sql

SELECT month(order_date) as month, category, sum(profit) as profit, sum(quantity) as quantity
FROM sales_order_detail a
JOIN sales_order_header b
ON a.order_id = b.order_id
GROUP BY month,category
ORDER BY profit,category,month
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>category</th><th>profit</th><th>quantity</th></tr></thead><tbody><tr><td>4</td><td>Furniture</td><td>-3425.0</td><td>63</td></tr><tr><td>5</td><td>Electronics</td><td>-2523.0</td><td>116</td></tr><tr><td>9</td><td>Furniture</td><td>-2468.0</td><td>83</td></tr><tr><td>6</td><td>Electronics</td><td>-2078.0</td><td>82</td></tr><tr><td>6</td><td>Clothing</td><td>-2036.0</td><td>235</td></tr><tr><td>7</td><td>Electronics</td><td>-1633.0</td><td>40</td></tr><tr><td>9</td><td>Clothing</td><td>-1585.0</td><td>192</td></tr><tr><td>8</td><td>Electronics</td><td>-1548.0</td><td>98</td></tr><tr><td>10</td><td>Furniture</td><td>-1316.0</td><td>50</td></tr><tr><td>8</td><td>Clothing</td><td>-1075.0</td><td>276</td></tr><tr><td>9</td><td>Electronics</td><td>-910.0</td><td>56</td></tr><tr><td>6</td><td>Furniture</td><td>-856.0</td><td>52</td></tr><tr><td>5</td><td>Furniture</td><td>-794.0</td><td>74</td></tr><tr><td>7</td><td>Furniture</td><td>-457.0</td><td>58</td></tr><tr><td>4</td><td>Electronics</td><td>-351.0</td><td>75</td></tr><tr><td>5</td><td>Clothing</td><td>-267.0</td><td>233</td></tr><tr><td>4</td><td>Clothing</td><td>-184.0</td><td>251</td></tr><tr><td>7</td><td>Clothing</td><td>-48.0</td><td>142</td></tr><tr><td>12</td><td>Furniture</td><td>187.0</td><td>43</td></tr><tr><td>8</td><td>Furniture</td><td>443.0</td><td>72</td></tr><tr><td>3</td><td>Furniture</td><td>1587.0</td><td>94</td></tr><tr><td>1</td><td>Clothing</td><td>1691.0</td><td>436</td></tr><tr><td>2</td><td>Clothing</td><td>1822.0</td><td>312</td></tr><tr><td>12</td><td>Clothing</td><td>1901.0</td><td>259</td></tr><tr><td>2</td><td>Electronics</td><td>1927.0</td><td>82</td></tr><tr><td>10</td><td>Clothing</td><td>2148.0</td><td>284</td></tr><tr><td>2</td><td>Furniture</td><td>2168.0</td><td>118</td></tr><tr><td>10</td><td>Electronics</td><td>2261.0</td><td>85</td></tr><tr><td>12</td><td>Electronics</td><td>3196.0</td><td>110</td></tr><tr><td>1</td><td>Furniture</td><td>3284.0</td><td>145</td></tr><tr><td>3</td><td>Electronics</td><td>3430.0</td><td>141</td></tr><tr><td>11</td><td>Clothing</td><td>3736.0</td><td>380</td></tr><tr><td>11</td><td>Electronics</td><td>3938.0</td><td>105</td></tr><tr><td>11</td><td>Furniture</td><td>3945.0</td><td>93</td></tr><tr><td>1</td><td>Electronics</td><td>4785.0</td><td>164</td></tr><tr><td>3</td><td>Clothing</td><td>5060.0</td><td>516</td></tr></tbody></table></div>

# %% [markdown]
# ## Query performance
# pre-joined 'denormalized' table; rank by partition
# ## SQL API
# partion, rank
# -- https://spark.apache.org/docs/latest/api/sql/index.html#dense_rank

# %%
# %sql

SELECT 
distinct 
category, month(order_date) as month, city, sum(quantity) OVER (PARTITION BY category, city,month(order_date)) as quantity
--,* --to check details
from sales_denorm
where category='Clothing' and month(order_date)=1
order by category, month, quantity desc

-- select * from sales_denorm where category='Clothing' and month(order_date)=1 order by quantity desc -- 110 rows
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>month</th><th>city</th><th>quantity</th></tr></thead><tbody><tr><td>Clothing</td><td>1</td><td>Indore</td><td>117</td></tr><tr><td>Clothing</td><td>1</td><td>Ahmedabad</td><td>48</td></tr><tr><td>Clothing</td><td>1</td><td>Delhi</td><td>48</td></tr><tr><td>Clothing</td><td>1</td><td>Allahabad</td><td>41</td></tr><tr><td>Clothing</td><td>1</td><td>Mumbai</td><td>39</td></tr><tr><td>Clothing</td><td>1</td><td>Kolkata</td><td>31</td></tr><tr><td>Clothing</td><td>1</td><td>Pune</td><td>26</td></tr><tr><td>Clothing</td><td>1</td><td>Chandigarh</td><td>23</td></tr><tr><td>Clothing</td><td>1</td><td>Hyderabad</td><td>19</td></tr><tr><td>Clothing</td><td>1</td><td>Surat</td><td>14</td></tr><tr><td>Clothing</td><td>1</td><td>Udaipur</td><td>8</td></tr><tr><td>Clothing</td><td>1</td><td>Goa</td><td>8</td></tr><tr><td>Clothing</td><td>1</td><td>Kohima</td><td>7</td></tr><tr><td>Clothing</td><td>1</td><td>Amritsar</td><td>4</td></tr><tr><td>Clothing</td><td>1</td><td>Simla</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
--so we can get target and actual sales amount; 
--get insights: check whether the target was met or not, potential forecast what could happen in near future at CATEGORY level

select t.category, t.year, t.month, t.target, a.total_sold_amount,
case 
  when t.target > a.total_sold_amount then 'not achieved'
  else 'achieved'
end as performance
FROM sales_target t
LEFT JOIN
(
  select category, month(order_date) as month, year(order_date) as year,sum(amount) as total_sold_amount
  from sales_denorm
  group by  category, year, month
) as a 
  on t.month = a.month
  and t.year = a.year
  and t.category=a.category
--where t.category='Furniture' and t.year=2018 and t.month=4
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>year</th><th>month</th><th>target</th><th>total_sold_amount</th><th>performance</th></tr></thead><tbody><tr><td>Furniture</td><td>2018</td><td>4</td><td>10400.0</td><td>8121.0</td><td>not achieved</td></tr><tr><td>Furniture</td><td>2018</td><td>5</td><td>10500.0</td><td>6220.0</td><td>not achieved</td></tr><tr><td>Furniture</td><td>2018</td><td>6</td><td>10600.0</td><td>5532.0</td><td>not achieved</td></tr><tr><td>Furniture</td><td>2018</td><td>7</td><td>10800.0</td><td>3483.0</td><td>not achieved</td></tr><tr><td>Furniture</td><td>2018</td><td>8</td><td>10900.0</td><td>9538.0</td><td>not achieved</td></tr><tr><td>Furniture</td><td>2018</td><td>9</td><td>11000.0</td><td>8704.0</td><td>not achieved</td></tr><tr><td>Furniture</td><td>2018</td><td>10</td><td>11100.0</td><td>6766.0</td><td>not achieved</td></tr><tr><td>Furniture</td><td>2018</td><td>11</td><td>11300.0</td><td>15165.0</td><td>achieved</td></tr><tr><td>Furniture</td><td>2018</td><td